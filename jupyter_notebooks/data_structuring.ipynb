# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
import os
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Import & Prepare DataFrame

# %%
def remove_whitespaces(df: pd.DataFrame) -> None:
    """Remove whitespaces from column names and string values

    Parameters
    ----------
    df : pd.DataFrame
        Dataframe to clean
    """
    # Remove whitespace from each column name
    df.columns = df.columns.str.strip()
    
    # Remove whitespace from each string value
    categorical_columns = df.select_dtypes("O").columns
    for column in categorical_columns:
        df[column] = df[column].str.strip()

# %%
MATCHES_DATA_PATH = "../data/matches_data/historical_matches.csv"
PLAYERS_DIR = "../data/players_data"

# Load the matches data
matches = pd.read_csv(MATCHES_DATA_PATH)

# Load the players data
all_files = glob.glob(os.path.join(PLAYERS_DIR , "*.csv"))
temp_list = []

for filename in all_files:
    temp_df = pd.read_csv(filename, index_col=None, header=0)
    year = int(filename.split(".")[-2][-2:]) + 2000
    temp_df["year"] = year


    temp_list.append(temp_df)

players = pd.concat(temp_list, axis=0, ignore_index=True)

# Remove whitespaces from column names and string values
remove_whitespaces(matches)
remove_whitespaces(players)

# %%
# Matches date to datetime
matches["date"] = pd.to_datetime(matches["date"])
matches["year"] = matches["date"].dt.year

# Filter years in matches to match the given players data dates [2015, 2022]
matches = matches[matches["year"] >= 2015]

# Filter tournaments to keep only ones  having players as in world cup matches
to_keep_tournaments = ["Friendly", 
"AFC Asian Cup qualification",
"EAFF Championship",
"African Cup of Nations qualification",
"FIFA World Cup",
"Kirin Challenge Cup",
"UEFA Euro qualification",
"Superclásico de las Américas",
"Gulf Cup",
"AFC Asian Cup",
"African Cup of Nations",
"FIFA World Cup qualification",
"Copa América",
"Gold Cup",
"Copa América qualification",
"Kirin Cup",
"UEFA Euro",
"Confederations Cup",
"UEFA Nations League",
"CONCACAF Nations League qualification",
"CONCACAF Nations League",
"CONMEBOL–UEFA Cup of Champions"]

# %%
## Assert all to_keep torunments are in dataframe
for torn in to_keep_tournaments:
    all_tournaments = matches["tournament"].unique()
    found = matches[matches["tournament"] == torn].count().sum()
    assert found > 0, f"Zero mathces found for tournament {torn}"
    assert (all_tournaments == torn).sum() == 1, f"tournament {torn} NOT found in matches"

# %%
# Filter matches to keep only the ones in the tournaments to keep
matches = matches[matches["tournament"].isin(to_keep_tournaments)]

# %%
matches.reset_index(drop=True, inplace=True)
players.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## Apply Structuring to Merge

# %%
# Get copies to merge
players_1 = players.copy()
players_2 = players.copy()

# %%
data = players_1.merge( matches, left_on="nationality_name", right_on="home_team")

# %%
players[(players["nationality_name"] == "Portugal") & (players["year"] == 2016)].to_csv("temp_csv.csv")

# %%
years = list(range(2015, 2023))
temp_list = []
zero_dict = {2015: [], 
             2016: [], 
             2017: [],
             2018: [],
             2019: [],
             2020: [],
             2021: [],
             2022: []}
for year in years:
    print("-"*20 + str(year) + "-"*20)
    for nation in (players["nationality_name"].unique()):
        
        count = players[(players["nationality_name"] == nation) & (players["year"] == year) & (~players["nation_position"].isna()) & (players["nation_position"]!= "SUB")]["sofifa_id"].nunique()
        
        # assert (count == 11) or (count == 0), f"{count} players for {nation} in {year}"
        
        # print(f"{nation} : {count}")
        # print("-"*20)


        if count not in [0,11]:
            temp_list.append(nation)
            print(f"{nation} : {count}")
            print("-"*20)
            print("FLAAAAAAAAAAAAG!!!!!")
        elif count == 0:
            zero_dict[year].append(nation)
# Out:
# --------------------2015--------------------
# --------------------2016--------------------
# Portugal : 10
# --------------------
# FLAAAAAAAAAAAAG!!!!!
# Brazil : 10
# --------------------
# FLAAAAAAAAAAAAG!!!!!
# Egypt : 10
# --------------------
# FLAAAAAAAAAAAAG!!!!!
# Hungary : 9
# --------------------
# FLAAAAAAAAAAAAG!!!!!
# Côte d'Ivoire : 10
# --------------------
# FLAAAAAAAAAAAAG!!!!!
# Greece : 10
# --------------------
# FLAAAAAAAAAAAAG!!!!!
# Czech Republic : 7
# --------------------
# FLAAAAAAAAAAAAG!!!!!
# Chile : 9
# --------------------
# FLAAAAAAAAAAAAG!!!!!
# New Zealand : 8
# --------------------
# FLAAAAAAAAAAAAG!!!!!
# Romania : 10
# --------------------
# FLAAAAAAAAAAAAG!!!!!
# Paraguay : 8
# --------------------
# FLAAAAAAAAAAAAG!!!!!
# South Africa : 9
# --------------------
# FLAAAAAAAAAAAAG!!!!!
# Bolivia : 9
# --------------------
# FLAAAAAAAAAAAAG!!!!!
# --------------------2017--------------------
# --------------------2018--------------------
# --------------------2019--------------------
# --------------------2020--------------------
# --------------------2021--------------------
# --------------------2022--------------------

# %%
temp_df = matches.copy()
for year in zero_dict.keys():
    temp_df = temp_df[~(temp_df["home_team"].isin(zero_dict[year]) & (temp_df["year"] == year))]
    temp_df = temp_df[~(temp_df["away_team"].isin(zero_dict[year]) & (temp_df["year"] == year))]

indicies_to_drop = temp_df[(temp_df["home_team"].isin(temp_list)) | temp_df["away_team"].isin(temp_list)].loc[temp_df["year"] == 2016].index
temp_df.drop(indicies_to_drop, inplace=True)

# %%
temp_df.shape[0]/matches.shape[0]
# Out:
# 0.21334418226200164

# %%
players[players["nationality_name"] == "Qatar"]
# Out:
#         sofifa_id                                         player_url  \
# 64267      234051  https://sofifa.com/player/234051/akram-afif/18...
# 66501      239861  https://sofifa.com/player/239861/abdelkarim-fa...
# 67535      245688  https://sofifa.com/player/245688/yasser-ahmed/...
# 69451      239862  https://sofifa.com/player/239862/hamza-sanhaji...
# 69497      241003  https://sofifa.com/player/241003/ahmad-moein/1...
# 70943      239878  https://sofifa.com/player/239878/assim-madibo/...
# 99115      234051  https://sofifa.com/player/234051/akram-afif/17...
# 105773     234043  https://sofifa.com/player/234043/fahad-al-abdu...
#
#                short_name                           long_name  \
# 64267             A. Afif                   Akram Hassan Afif
# 66501         A. Fadlalla   Abdelkarim Hassan Al Haj Fadlalla
# 67535            Y. Ahmed  Ahmed Yasser Mohammedi Abdelrehman
# 69451          H. Sanhaji                       Hamza Sanhaji
# 69497            A. Moein               Ahmed Moein Doozandeh
# 70943           A. Madibo            Assim Omer Al Haj Madibo
# 99115             A. Afif                   Akram Hassan Afif
# 105773  F. Al Abdulrahman    Fahad Ali Shonain Al Abdulrahman
#
#        player_positions  overall  potential  value_eur  wage_eur  age  ...  \
# 64267            LM, RM       68         77  1400000.0    7000.0   20  ...
# 66501           LB, LWB       66         72   750000.0    3000.0   23  ...
# 67535                CB       65         70   625000.0    3000.0   23  ...
# 69451        ST, LM, RM       63         68   500000.0    3000.0   23  ...
# 69497                CM       63         72   550000.0    2000.0   21  ...
# 70943               CDM       61         70   350000.0    2000.0   20  ...
# 99115            LW, ST       69         79  1500000.0   10000.0   19  ...
# 105773               LB       62         69   325000.0    2000.0   21  ...
#
#           cb   rcb    rb    gk  \
# 64267   42+1  42+1  48+1  15+1
# 66501   65+1  65+1  65+1  15+1
# 67535   64+1  64+1  61+1  14+1
# 69451   35+1  35+1  41+1  14+1
# 69497   53+1  53+1  57+1  16+1
# 70943   59+1  59+1  57+1  16+1
# 99115   41+1  41+1  48+1  15+1
# 105773  56+1  56+1  61+1  16+1
#
#                                           player_face_url  \
# 64267   https://cdn.sofifa.net/players/234/051/18_120.png
# 66501   https://cdn.sofifa.net/players/239/861/18_120.png
# 67535   https://cdn.sofifa.net/players/245/688/18_120.png
# 69451   https://cdn.sofifa.net/players/239/862/18_120.png
# 69497   https://cdn.sofifa.net/players/241/003/18_120.png
# 70943   https://cdn.sofifa.net/players/239/878/18_120.png
# 99115   https://cdn.sofifa.net/players/234/051/17_120.png
# 105773  https://cdn.sofifa.net/players/234/043/17_120.png
#
#                                     club_logo_url  \
# 64267    https://cdn.sofifa.net/teams/2013/60.png
# 66501    https://cdn.sofifa.net/teams/2013/60.png
# 67535   https://cdn.sofifa.net/teams/15012/60.png
# 69451    https://cdn.sofifa.net/teams/2013/60.png
# 69497   https://cdn.sofifa.net/teams/15012/60.png
# 70943    https://cdn.sofifa.net/teams/2013/60.png
# 99115     https://cdn.sofifa.net/teams/459/60.png
# 105773   https://cdn.sofifa.net/teams/2013/60.png
#
#                               club_flag_url nation_logo_url  \
# 64267   https://cdn.sofifa.net/flags/be.png             NaN
# 66501   https://cdn.sofifa.net/flags/be.png             NaN
# 67535   https://cdn.sofifa.net/flags/es.png             NaN
# 69451   https://cdn.sofifa.net/flags/be.png             NaN
# 69497   https://cdn.sofifa.net/flags/es.png             NaN
# 70943   https://cdn.sofifa.net/flags/be.png             NaN
# 99115   https://cdn.sofifa.net/flags/es.png             NaN
# 105773  https://cdn.sofifa.net/flags/be.png             NaN
#
#                             nation_flag_url  year
# 64267   https://cdn.sofifa.net/flags/qa.png  2018
# 66501   https://cdn.sofifa.net/flags/qa.png  2018
# 67535   https://cdn.sofifa.net/flags/qa.png  2018
# 69451   https://cdn.sofifa.net/flags/qa.png  2018
# 69497   https://cdn.sofifa.net/flags/qa.png  2018
# 70943   https://cdn.sofifa.net/flags/qa.png  2018
# 99115   https://cdn.sofifa.net/flags/qa.png  2017
# 105773  https://cdn.sofifa.net/flags/qa.png  2017
#
# [8 rows x 111 columns]

# %%
"D. Clair"
players[(players["year"] == 2022) & (players["nationality_name"] == "Canada")]["long_name"].unique()
# Out:
# array(['Alphonso Boyle Davies', 'Jonathan Christian David',
#        'Atiba Hutchinson', 'Milan Borjan', 'Stephen Antunes Eustáquio',
#        'Cyle Christopher Larin', 'Scott Harry Nathaniel Arfield',
#        'Lucas Daniel Cavallini', 'Maxime Crépeau', 'David Junior Hoilett',
#        'Jonathan Osorio', 'Samuel Piette', 'Richie Mamah Laryea',
#        'Mark-Anthony Kaye', 'Doneil Jor-Dee Ashley Henry',
#        'David Wotherspoon', 'Samuel Ayomide Adekugbe',
#        'Cristián Daniel Gutiérrez Zúñiga', 'Zachary Brault-Guillard',
#        'Tajon Buchanan', 'Dayne St. Clair', 'Kamal Anthony Miller',
#        'Tesho Akindele', 'Caniggia Ginola Elva', 'Russell Teibert',
#        'Ricardo José Araújo Ferreira', 'Manjrekar James',
#        'Liam Alan Millar', 'Ayomide Akinola', 'Alistair Johnston',
#        'Scott Fitzgerald Kennedy', 'Steven de Sousa Vitória',
#        'Tyler Geoffrey Pasher', 'Liam Fraser', 'Derek Cornelius',
#        'Jayson Leutwiler', 'Raheem Edwards', 'Ashtone Morgan',
#        'James Pantemis', 'Simon Edmund Thomas', 'Kianz González-Froese',
#        'Jay Chapman', 'Ballou Jean-Yves Tabla',
#        'Marcus Valdez Pereira Godinho', 'Harrison Theodore Paton',
#        'Juan Guillermo Córdova Torres', 'Michael Baldisimo',
#        'Mathieu Choinière', 'Thomas Hasal', 'Joel Waterman',
#        'Tosaint Ricketts', 'Kosovar Sadiki', 'Jacob Shaffelburg',
#        'Jayden Nelson', 'Ralph Priso-Mbongue', 'Gloire Amanda',
#        'Zohran Ludovic Bassong', 'Ryan Raposo', 'Noble Okello',
#        'Theodor Alexander Corbeanu', 'Carson Buschman-Dormond',
#        'Justin Smith', 'Jahkeele Marshall-Rutty', 'Sebastian Breza',
#        'Clément Bayiha', 'Luke Singh', 'Damiano Pecile',
#        'Jordan Perruzza', 'Kyriakos Stamatopoulos', 'Patrick Metcalfe',
#        'Kamron Habibullah', 'Ben Paton', 'Rida Zouhir', 'Isaac Boehmer',
#        'Matteo Campagna', 'Nathan-Dylan Saliba'], dtype=object)

# %%
temp_df["home_team"].unique()
# Out:
# array(['Cameroon', 'Sweden', 'Australia', 'Finland', 'Cape Verde',
#        'Yemen', 'Chile', 'DR Congo', 'Timor-Leste', 'India', 'Brunei',
#        'Mongolia', 'Nepal', 'Pakistan', 'Botswana', 'Denmark', 'Germany',
#        'Scotland', 'Eswatini', 'France', 'Bulgaria', 'Netherlands',
#        'Brazil', 'Dominica', 'Hungary', 'Republic of Ireland',
#        'Northern Ireland', 'Italy', 'South Korea', 'Peru', 'Portugal',
#        'Switzerland', 'United States', 'Lesotho', 'Bangladesh',
#        'Singapore', 'Norway', 'Turkey', 'Laos', 'Mexico', 'Wales',
#        'Argentina', 'Colombia', 'Russia', 'Slovenia', 'Ecuador',
#        'Myanmar', 'Poland', 'Uruguay', 'Bolivia', 'Greece', 'Romania',
#        'England', 'Venezuela', 'Djibouti', 'Czech Republic',
#        'North Korea', 'Paraguay', 'Belgium', 'Spain', 'Austria',
#        'Martinique', 'Catalonia', 'Maldives', 'Guadeloupe',
#        'Sint Maarten', 'China PR', 'Canada', 'Seychelles', 'Galicia',
#        'Corsica', 'Northern Mariana Islands', 'Taiwan', 'Tahiti',
#        'Solomon Islands', 'Ivory Coast', 'Egypt', 'South Africa',
#        'Vatican City', 'French Guiana', 'Curaçao', 'Yorkshire', 'Barawa',
#        'Saudi Arabia', 'Iceland', 'Anguilla',
#        'United States Virgin Islands', 'Saint Martin', 'Basque Country',
#        'Parishes of Jersey', 'Bahamas', 'British Virgin Islands',
#        'Kernow', 'Cascadia', 'Vanuatu', 'Ynys Môn',
#        'São Tomé and Príncipe', 'Bonaire', 'Turks and Caicos Islands',
#        'Guinea-Bissau', 'Cayman Islands', 'Cook Islands', 'New Zealand',
#        'Ukraine'], dtype=object)

# %%
players.shape[1] + matches.shape[1]
# Out:
# 121

# %%
pd.merge([players])
# Out:
#         sofifa_id                                         player_url  \
# 0          158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          188545  https://sofifa.com/player/188545/robert-lewand...
# 2           20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3          190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4          192985  https://sofifa.com/player/192985/kevin-de-bruy...
# ...           ...                                                ...
# 142074     220806  https://sofifa.com/player/220806/ellis-redman/...
# 142075     225509  https://sofifa.com/player/225509/aaron-collins...
# 142076     201197  https://sofifa.com/player/201197/paul-tisdale/...
# 142077     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
# 142078     222947  https://sofifa.com/player/222947/tom-davies/15...
#
#                short_name                            long_name  \
# 0                L. Messi       Lionel Andrés Messi Cuccittini
# 1          R. Lewandowski                   Robert Lewandowski
# 2       Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 3               Neymar Jr        Neymar da Silva Santos Júnior
# 4            K. De Bruyne                      Kevin De Bruyne
# ...                   ...                                  ...
# 142074          E. Redman                         Ellis Redman
# 142075         A. Collins            Aaron Graham John Collins
# 142076         P. Tisdale                         Paul Tisdale
# 142077           P. Żemło                          Piotr Żemło
# 142078          T. Davies            Thomas Christopher Davies
#
#        player_positions  overall  potential    value_eur  wage_eur  age  ...  \
# 0            RW, ST, CF       93         93   78000000.0  320000.0   34  ...
# 1                    ST       92         92  119500000.0  270000.0   32  ...
# 2                ST, LW       91         91   45000000.0  270000.0   36  ...
# 3               LW, CAM       91         91  129000000.0  270000.0   29  ...
# 4               CM, CAM       91         91  125500000.0  350000.0   30  ...
# ...                 ...      ...        ...          ...       ...  ...  ...
# 142074               CB       41         61      20000.0    2000.0   17  ...
# 142075               ST       41         50      30000.0    2000.0   17  ...
# 142076          CM, CAM       40         40          NaN    2000.0   41  ...
# 142077           LM, LB       40         50      15000.0    2000.0   18  ...
# 142078               CB       40         49      15000.0    2000.0   22  ...
#
#           cb   rcb    rb    gk  \
# 0       50+3  50+3  61+3  19+3
# 1       60+3  60+3  61+3  19+3
# 2       53+3  53+3  60+3  20+3
# 3       50+3  50+3  62+3  20+3
# 4       69+3  69+3  75+3  21+3
# ...      ...   ...   ...   ...
# 142074    41    41    40   NaN
# 142075    31    31    32   NaN
# 142076    33    33    34   NaN
# 142077  53-3  53-3  51-1   NaN
# 142078    40    40    39   NaN
#
#                                           player_face_url  \
# 0       https://cdn.sofifa.net/players/158/023/22_120.png
# 1       https://cdn.sofifa.net/players/188/545/22_120.png
# 2       https://cdn.sofifa.net/players/020/801/22_120.png
# 3       https://cdn.sofifa.net/players/190/871/22_120.png
# 4       https://cdn.sofifa.net/players/192/985/22_120.png
# ...                                                   ...
# 142074  https://cdn.sofifa.net/players/220/806/15_120.png
# 142075  https://cdn.sofifa.net/players/225/509/15_120.png
# 142076  https://cdn.sofifa.net/players/201/197/15_120.png
# 142077  https://cdn.sofifa.net/players/217/591/15_120.png
# 142078  https://cdn.sofifa.net/players/222/947/15_120.png
#
#                                      club_logo_url  \
# 0           https://cdn.sofifa.net/teams/73/60.png
# 1           https://cdn.sofifa.net/teams/21/60.png
# 2           https://cdn.sofifa.net/teams/11/60.png
# 3           https://cdn.sofifa.net/teams/73/60.png
# 4           https://cdn.sofifa.net/teams/10/60.png
# ...                                            ...
# 142074  https://cdn.sofifa.net/teams/112254/60.png
# 142075  https://cdn.sofifa.net/teams/112254/60.png
# 142076     https://cdn.sofifa.net/teams/143/60.png
# 142077    https://cdn.sofifa.net/teams/1873/60.png
# 142078  https://cdn.sofifa.net/teams/112260/60.png
#
#                                   club_flag_url  \
# 0           https://cdn.sofifa.net/flags/fr.png
# 1           https://cdn.sofifa.net/flags/de.png
# 2       https://cdn.sofifa.net/flags/gb-eng.png
# 3           https://cdn.sofifa.net/flags/fr.png
# 4       https://cdn.sofifa.net/flags/gb-eng.png
# ...                                         ...
# 142074  https://cdn.sofifa.net/flags/gb-eng.png
# 142075  https://cdn.sofifa.net/flags/gb-eng.png
# 142076  https://cdn.sofifa.net/flags/gb-eng.png
# 142077      https://cdn.sofifa.net/flags/pl.png
# 142078  https://cdn.sofifa.net/flags/gb-eng.png
#
#                                  nation_logo_url  \
# 0       https://cdn.sofifa.net/teams/1369/60.png
# 1       https://cdn.sofifa.net/teams/1353/60.png
# 2       https://cdn.sofifa.net/teams/1354/60.png
# 3                                            NaN
# 4       https://cdn.sofifa.net/teams/1325/60.png
# ...                                          ...
# 142074                                       NaN
# 142075                                       NaN
# 142076                                       NaN
# 142077                                       NaN
# 142078                                       NaN
#
#                                 nation_flag_url  year
# 0           https://cdn.sofifa.net/flags/ar.png  2022
# 1           https://cdn.sofifa.net/flags/pl.png  2022
# 2           https://cdn.sofifa.net/flags/pt.png  2022
# 3           https://cdn.sofifa.net/flags/br.png  2022
# 4           https://cdn.sofifa.net/flags/be.png  2022
# ...                                         ...   ...
# 142074  https://cdn.sofifa.net/flags/gb-wls.png  2015
# 142075  https://cdn.sofifa.net/flags/gb-wls.png  2015
# 142076      https://cdn.sofifa.net/flags/mt.png  2015
# 142077      https://cdn.sofifa.net/flags/pl.png  2015
# 142078  https://cdn.sofifa.net/flags/gb-eng.png  2015
#
# [142079 rows x 111 columns]
